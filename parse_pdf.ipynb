# %%
from tabula import read_pdf
import pandas as pd

df = read_pdf('SummaryReport.pdf', pages='5-12', guess=False, pandas_options={'header': None})

# %%
import json

with open('lookup.json') as f:
    lookup = json.load(f)

lookup_race = pd.DataFrame(
        [{'key': key, **val} for (key, val) in lookup['races'].items()]
    ).set_index('key', drop=True)

lookup_candidate = pd.DataFrame(
        [{'key': key, **val} for (key, val) in lookup['candidates'].items()]
    ).append(
        {'cboe_results_name': 'WRITE-IN', 'chi_vote_name': 'Write-in', 'key': '0000000'},
        ignore_index=True
    ).set_index('key', drop=True)

# %%
import re
from collections import defaultdict
from pprint import PrettyPrinter

pp = PrettyPrinter(indent=4)

# Python program to illustrate the intersection 
# of two lists 
def intersection(lst1, lst2): 
  
    # Use of hybrid method 
    temp = set(lst2) 
    lst3 = [value for value in lst1 if value in temp] 
    return lst3 

#format df
iterator = df.iterrows()

contests = defaultdict(dict)

race_id = None

for idx, row in iterator:
    series = pd.Series(row)
    if series.str.contains('precincts counted').any():
        try:
            # get race name by matching to lookup
            race_name = intersection(series.values, lookup_race.cboe_results_name.values)[0]
        except IndexError:
            break
        
        # get race id using lookup
        race_id = lookup_race[lookup_race.cboe_results_name==race_name].index.values[0]
        
        # get precincts figures
        prs_str = series[series.str.contains('precincts counted', na=False)].values[0]
        prs_rpt, prs_tot = map(int, re.findall('\d+', prs_str))
        
        contests[race_id]['meta'] = [race_name, prs_rpt, prs_tot]
        contests[race_id]['cands'] = []
        
#     if race_id and series.str.match(r'^[A-Z -\.]+$').any():
    if race_id:
        try:
            cand_cboe_name = intersection(series.values, lookup_candidate.cboe_results_name.values)[0]
            cand_name = lookup_candidate[lookup_candidate.cboe_results_name == cand_cboe_name].chi_vote_name.values[0]
            
            vote_str = series[series.str.match('^[\d,]+$', na=False)]
            vote_cnt = pd.to_numeric(vote_str.str.replace(',', '')).values[0]
            
            pct_str = series[series.str.contains('%', na=False)].values[0]
            
            contests[race_id]['cands'].append([cand_name, vote_cnt, pct_str])
            
        except IndexError: # no match
            print(race_name, series)
            pass
        
    if race_id and series.str.contains('Total').any():
        # get total
        tot_str = series[series.str.match('[\d,]+', na=False)]
        vote_tot = pd.to_numeric(tot_str.str.replace(',', '')).values[0]
        contests[race_id]['meta'].append(vote_tot)
        
        contests[race_id]['cands'] = sorted(contests[race_id]['cands'], key=lambda x: x[1], reverse=True)
        
pp.pprint(contests)
# Out:
# Mayor 0                              Mayor
# 1    2069 of 2069  precincts counted
# 2                                NaN
# 3                            100.00%
# 4                                NaN
# Name: 9, dtype: object
# Mayor 0        NaN
# 1      Total
# 2    556,844
# 3        NaN
# 4        NaN
# Name: 25, dtype: object
# Clerk 0                              Clerk
# 1    2069 of 2069  precincts counted
# 2                                NaN
# 3                            100.00%
# 4                                NaN
# Name: 26, dtype: object
# Clerk 0        NaN
# 1      Total
# 2    264,706
# 3        NaN
# 4        NaN
# Name: 29, dtype: object
# Treasurer 0                          Treasurer
# 1    2069 of 2069  precincts counted
# 2                                NaN
# 3                            100.00%
# 4                                NaN
# Name: 30, dtype: object
# Treasurer 0        NaN
# 1      Total
# 2    509,216
# 3        NaN
# 4        NaN
# Name: 35, dtype: object
# Alderman 1st Ward 0              Alderman 1st Ward
# 1    44 of 44  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 36, dtype: object
# Alderman 1st Ward 0       NaN
# 1     Total
# 2    11,964
# 3       NaN
# 4       NaN
# Name: 40, dtype: object
# Alderman 2nd Ward 0              Alderman 2nd Ward
# 1    46 of 46  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 41, dtype: object
# Alderman 2nd Ward 0       NaN
# 1     Total
# 2    10,981
# 3       NaN
# 4       NaN
# Name: 44, dtype: object
# Alderman 2nd Ward 0    PROCLAMATION
# 1             NaN
# 2             NaN
# 3             NaN
# 4    Page 5 of 18
# Name: 45, dtype: object
# Alderman 3rd Ward 0              Alderman 3rd Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 46, dtype: object
# Alderman 3rd Ward 0       NaN
# 1     Total
# 2    13,167
# 3       NaN
# 4       NaN
# Name: 50, dtype: object
# Alderman 4th Ward 0              Alderman 4th Ward
# 1    38 of 38  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 51, dtype: object
# Alderman 4th Ward 0       NaN
# 1     Total
# 2    13,886
# 3       NaN
# 4       NaN
# Name: 55, dtype: object
# Alderman 5th Ward 0              Alderman 5th Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 56, dtype: object
# Alderman 5th Ward 0       NaN
# 1     Total
# 2    12,954
# 3       NaN
# 4       NaN
# Name: 61, dtype: object
# Alderman 6th Ward 0              Alderman 6th Ward
# 1    48 of 48  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 62, dtype: object
# Alderman 6th Ward 0       NaN
# 1     Total
# 2    10,119
# 3       NaN
# 4       NaN
# Name: 67, dtype: object
# Alderman 7th Ward 0              Alderman 7th Ward
# 1    46 of 46  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 68, dtype: object
# Alderman 7th Ward 0       NaN
# 1     Total
# 2    10,082
# 3       NaN
# 4       NaN
# Name: 73, dtype: object
# Alderman 8th Ward 0              Alderman 8th Ward
# 1    56 of 56  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 74, dtype: object
# Alderman 8th Ward 0       NaN
# 1     Total
# 2    13,555
# 3       NaN
# 4       NaN
# Name: 80, dtype: object
# Alderman 9th Ward 0              Alderman 9th Ward
# 1    51 of 51  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 81, dtype: object
# Alderman 9th Ward 0       NaN
# 1     Total
# 2    11,431
# 3       NaN
# 4       NaN
# Name: 87, dtype: object
# Alderman 10th Ward 0             Alderman 10th Ward
# 1    36 of 36  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 88, dtype: object
# Alderman 10th Ward 0      NaN
# 1    Total
# 2    8,413
# 3      NaN
# 4      NaN
# Name: 92, dtype: object
# Alderman 10th Ward 0    PROCLAMATION
# 1             NaN
# 2             NaN
# 3             NaN
# 4    Page 6 of 18
# Name: 93, dtype: object
# Alderman 11th Ward 0             Alderman 11th Ward
# 1    38 of 38  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 94, dtype: object
# Alderman 11th Ward 0       NaN
# 1     Total
# 2    10,263
# 3       NaN
# 4       NaN
# Name: 98, dtype: object
# Alderman 12th Ward 0             Alderman 12th Ward
# 1    23 of 23  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 99, dtype: object
# Alderman 12th Ward 0      NaN
# 1    Total
# 2    5,949
# 3      NaN
# 4      NaN
# Name: 105, dtype: object
# Alderman 13th Ward 0             Alderman 13th Ward
# 1    48 of 48  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 106, dtype: object
# Alderman 13th Ward 0       NaN
# 1     Total
# 2    12,505
# 3       NaN
# 4       NaN
# Name: 110, dtype: object
# Alderman 14th Ward 0             Alderman 14th Ward
# 1    31 of 31  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 111, dtype: object
# Alderman 14th Ward 0      NaN
# 1    Total
# 2    7,221
# 3      NaN
# 4      NaN
# Name: 116, dtype: object
# Alderman 15th Ward 0             Alderman 15th Ward
# 1    24 of 24  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 117, dtype: object
# Alderman 15th Ward 0      NaN
# 1    Total
# 2    5,113
# 3      NaN
# 4      NaN
# Name: 124, dtype: object
# Alderman 16th Ward 0             Alderman 16th Ward
# 1    36 of 36  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 125, dtype: object
# Alderman 16th Ward 0      NaN
# 1    Total
# 2    5,585
# 3      NaN
# 4      NaN
# Name: 133, dtype: object
# Alderman 17th Ward 0             Alderman 17th Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 134, dtype: object
# Alderman 17th Ward 0      NaN
# 1    Total
# 2    7,910
# 3      NaN
# 4      NaN
# Name: 138, dtype: object
# Alderman 17th Ward 0    PROCLAMATION
# 1             NaN
# 2             NaN
# 3             NaN
# 4    Page 7 of 18
# Name: 139, dtype: object
# Alderman 18th Ward 0             Alderman 18th Ward
# 1    50 of 50  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 140, dtype: object
# Alderman 18th Ward 0       NaN
# 1     Total
# 2    11,957
# 3       NaN
# 4       NaN
# Name: 144, dtype: object
# Alderman 19th Ward 0             Alderman 19th Ward
# 1    57 of 57  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 145, dtype: object
# Alderman 19th Ward 0       NaN
# 1     Total
# 2    20,710
# 3       NaN
# 4       NaN
# Name: 149, dtype: object
# Alderman 20th Ward 0             Alderman 20th Ward
# 1    39 of 39  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 150, dtype: object
# Alderman 20th Ward 0      NaN
# 1    Total
# 2    7,484
# 3      NaN
# 4      NaN
# Name: 161, dtype: object
# Alderman 21st Ward 0             Alderman 21st Ward
# 1    54 of 54  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 162, dtype: object
# Alderman 21st Ward 0       NaN
# 1     Total
# 2    12,440
# 3       NaN
# 4       NaN
# Name: 168, dtype: object
# Alderman 22nd Ward 0             Alderman 22nd Ward
# 1    25 of 25  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 169, dtype: object
# Alderman 22nd Ward 0      NaN
# 1    Total
# 2    4,865
# 3      NaN
# 4      NaN
# Name: 175, dtype: object
# Alderman 23rd Ward 0             Alderman 23rd Ward
# 1    39 of 39  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 176, dtype: object
# Alderman 23rd Ward 0      NaN
# 1    Total
# 2    8,804
# 3      NaN
# 4      NaN
# Name: 180, dtype: object
# Alderman 24th Ward 0             Alderman 24th Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 181, dtype: object
# Alderman 24th Ward 0      NaN
# 1    Total
# 2    6,359
# 3      NaN
# 4      NaN
# Name: 187, dtype: object
# Alderman 24th Ward 0    PROCLAMATION
# 1             NaN
# 2             NaN
# 3             NaN
# 4    Page 8 of 18
# Name: 188, dtype: object
# Alderman 25th Ward 0             Alderman 25th Ward
# 1    32 of 32  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 189, dtype: object
# Alderman 25th Ward 0      NaN
# 1    Total
# 2    9,870
# 3      NaN
# 4      NaN
# Name: 196, dtype: object
# Alderman 26th Ward 0             Alderman 26th Ward
# 1    49 of 49  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 197, dtype: object
# Alderman 26th Ward 0      NaN
# 1    Total
# 2    8,769
# 3      NaN
# 4      NaN
# Name: 202, dtype: object
# Alderman 27th Ward 0             Alderman 27th Ward
# 1    50 of 50  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 203, dtype: object
# Alderman 27th Ward 0       NaN
# 1     Total
# 2    10,164
# 3       NaN
# 4       NaN
# Name: 207, dtype: object
# Alderman 28th Ward 0             Alderman 28th Ward
# 1    46 of 46  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 208, dtype: object
# Alderman 28th Ward 0      NaN
# 1    Total
# 2    8,095
# 3      NaN
# 4      NaN
# Name: 214, dtype: object
# Alderman 29th Ward 0             Alderman 29th Ward
# 1    44 of 44  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 215, dtype: object
# Alderman 29th Ward 0       NaN
# 1     Total
# 2    10,619
# 3       NaN
# 4       NaN
# Name: 220, dtype: object
# Alderman 30th Ward 0             Alderman 30th Ward
# 1    32 of 32  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 221, dtype: object
# Alderman 30th Ward 0      NaN
# 1    Total
# 2    7,438
# 3      NaN
# 4      NaN
# Name: 226, dtype: object
# Alderman 31st Ward 0             Alderman 31st Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 227, dtype: object
# Alderman 31st Ward 0      NaN
# 1    Total
# 2    6,419
# 3      NaN
# 4      NaN
# Name: 232, dtype: object
# Alderman 31st Ward 0    PROCLAMATION
# 1             NaN
# 2             NaN
# 3             NaN
# 4    Page 9 of 18
# Name: 233, dtype: object
# Alderman 32nd Ward 0             Alderman 32nd Ward
# 1    43 of 43  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 234, dtype: object
# Alderman 32nd Ward 0       NaN
# 1     Total
# 2    11,519
# 3       NaN
# 4       NaN
# Name: 237, dtype: object
# Alderman 33rd Ward 0             Alderman 33rd Ward
# 1    28 of 28  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 238, dtype: object
# Alderman 33rd Ward 0       NaN
# 1     Total
# 2    10,935
# 3       NaN
# 4       NaN
# Name: 243, dtype: object
# Alderman 34th Ward 0             Alderman 34th Ward
# 1    53 of 53  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 244, dtype: object
# Alderman 34th Ward 0       NaN
# 1     Total
# 2    11,612
# 3       NaN
# 4       NaN
# Name: 248, dtype: object
# Alderman 35th Ward 0             Alderman 35th Ward
# 1    31 of 31  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 249, dtype: object
# Alderman 35th Ward 0      NaN
# 1    Total
# 2    7,908
# 3      NaN
# 4      NaN
# Name: 253, dtype: object
# Alderman 36th Ward 0             Alderman 36th Ward
# 1    30 of 30  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 254, dtype: object
# Alderman 36th Ward 0      NaN
# 1    Total
# 2    5,377
# 3      NaN
# 4      NaN
# Name: 257, dtype: object
# Alderman 37th Ward 0             Alderman 37th Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 258, dtype: object
# Alderman 37th Ward 0      NaN
# 1    Total
# 2    7,675
# 3      NaN
# 4      NaN
# Name: 263, dtype: object
# Alderman 38th Ward 0             Alderman 38th Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 264, dtype: object
# Alderman 38th Ward 0      NaN
# 1    Total
# 2    9,340
# 3      NaN
# 4      NaN
# Name: 267, dtype: object
# Alderman 39th Ward 0             Alderman 39th Ward
# 1    45 of 45  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 268, dtype: object
# Alderman 39th Ward 0       NaN
# 1     Total
# 2    13,241
# 3       NaN
# 4       NaN
# Name: 274, dtype: object
# Alderman 39th Ward 0     PROCLAMATION
# 1              NaN
# 2              NaN
# 3    Page 10 of 18
# 4              NaN
# Name: 275, dtype: object
# Alderman 40th Ward 0             Alderman 40th Ward
# 1    39 of 39  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 276, dtype: object
# Alderman 40th Ward 0       NaN
# 1     Total
# 2    13,353
# 3       NaN
# 4       NaN
# Name: 283, dtype: object
# Alderman 41st Ward 0             Alderman 41st Ward
# 1    47 of 47  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 284, dtype: object
# Alderman 41st Ward 0       NaN
# 1     Total
# 2    17,791
# 3       NaN
# 4       NaN
# Name: 288, dtype: object
# Alderman 42nd Ward 0             Alderman 42nd Ward
# 1    42 of 42  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 289, dtype: object
# Alderman 42nd Ward 0       NaN
# 1     Total
# 2    11,129
# 3       NaN
# 4       NaN
# Name: 292, dtype: object
# Alderman 43rd Ward 0             Alderman 43rd Ward
# 1    46 of 46  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 293, dtype: object
# Alderman 43rd Ward 0       NaN
# 1     Total
# 2    14,073
# 3       NaN
# 4       NaN
# Name: 301, dtype: object
# Alderman 44th Ward 0             Alderman 44th Ward
# 1    41 of 41  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 302, dtype: object
# Alderman 44th Ward 0       NaN
# 1     Total
# 2    15,105
# 3       NaN
# 4       NaN
# Name: 307, dtype: object
# Alderman 45th Ward 0             Alderman 45th Ward
# 1    48 of 48  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 308, dtype: object
# Alderman 45th Ward 0       NaN
# 1     Total
# 2    14,865
# 3       NaN
# 4       NaN
# Name: 314, dtype: object
# Alderman 46th Ward 0             Alderman 46th Ward
# 1    40 of 40  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 315, dtype: object
# Alderman 46th Ward 0       NaN
# 1     Total
# 2    13,801
# 3       NaN
# 4       NaN
# Name: 323, dtype: object
# Alderman 46th Ward 0     PROCLAMATION
# 1              NaN
# 2              NaN
# 3    Page 11 of 18
# 4              NaN
# Name: 324, dtype: object
# Alderman 47th Ward 0             Alderman 47th Ward
# 1    48 of 48  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 325, dtype: object
# Alderman 47th Ward 0       NaN
# 1     Total
# 2    19,297
# 3       NaN
# 4       NaN
# Name: 336, dtype: object
# Alderman 48th Ward 0             Alderman 48th Ward
# 1    46 of 46  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 337, dtype: object
# Alderman 48th Ward 0       NaN
# 1     Total
# 2    14,859
# 3       NaN
# 4       NaN
# Name: 341, dtype: object
# Alderman 49th Ward 0             Alderman 49th Ward
# 1    33 of 33  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 342, dtype: object
# Alderman 49th Ward 0       NaN
# 1     Total
# 2    12,341
# 3       NaN
# 4       NaN
# Name: 346, dtype: object
# Alderman 50th Ward 0             Alderman 50th Ward
# 1    40 of 40  precincts counted
# 2                            NaN
# 3                        100.00%
# 4                            NaN
# Name: 347, dtype: object
# Alderman 50th Ward 0      NaN
# 1    Total
# 2    9,134
# 3      NaN
# 4      NaN
# Name: 352, dtype: object
# defaultdict(<class 'dict'>,
#             {   '0010': {   'cands': [   ['Lori Lightfoot', 97667, '17.54%'],
#                                          ['Toni Preckwinkle', 89343, '16.04%'],
#                                          ['William M. Daley', 82294, '14.78%'],
#                                          ['Willie L. Wilson', 59072, '10.61%'],
#                                          ['Susana A. Mendoza', 50373, '9.05%'],
#                                          ['Amara Enyia', 44589, '8.01%'],
#                                          ['Jerry Joyce', 40099, '7.20%'],
#                                          ['Gery Chico', 34521, '6.20%'],
#                                          ['Paul Vallas', 30236, '5.43%'],
#                                          ['Garry McCarthy', 14784, '2.65%'],
#                                          ['La Shawn K. Ford', 5606, '1.01%'],
#                                          [   'Robert "Bob" Fioretti',
#                                              4302,
#                                              '0.77%'],
#                                          ['John Kenneth Kozlar', 2349, '0.42%'],
#                                          ['Neal Sáles-Griffin', 1523, '0.27%'],
#                                          ['Write-in', 86, '0.02%']],
#                             'meta': ['Mayor', 2069, 2069, 556844]},
#                 '0011': {   'cands': [   [   'Anna M. Valencia*',
#                                              264319,
#                                              '99.85%'],
#                                          ['Write-in', 387, '0.15%']],
#                             'meta': ['Clerk', 2069, 2069, 264706]},
#                 '0012': {   'cands': [   [   'Melissa Conyears-Ervin',
#                                              225385,
#                                              '44.26%'],
#                                          ['Ameya Pawar', 211759, '41.59%'],
#                                          ['Peter Gariepy', 72068, '14.15%'],
#                                          ['Write-in', 4, '0.00%']],
#                             'meta': ['Treasurer', 2069, 2069, 509216]},
#                 '0013': {   'cands': [   ['Daniel La Spata', 7326, '61.23%'],
#                                          [   'Proco "Joe" Moreno*',
#                                              4635,
#                                              '38.74%'],
#                                          ['Write-in', 3, '0.03%']],
#                             'meta': ['Alderman 1st Ward', 44, 44, 11964]},
#                 '0014': {   'cands': [   ['Brian Hopkins*', 10977, '99.96%'],
#                                          ['Write-in', 4, '0.04%']],
#                             'meta': ['Alderman 2nd Ward', 46, 46, 10981]},
#                 '0015': {   'cands': [   [   'Patricia "Pat" Dowell*',
#                                              9085,
#                                              '69.00%'],
#                                          ['Alexandria Willis', 4079, '30.98%'],
#                                          ['Write-in', 3, '0.02%']],
#                             'meta': ['Alderman 3rd Ward', 41, 41, 13167]},
#                 '0016': {   'cands': [   ['Sophia King*', 9178, '66.10%'],
#                                          ['Ebony D. Lucas', 4708, '33.90%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 4th Ward', 38, 38, 13886]},
#                 '0017': {   'cands': [   [   'Leslie A.  Hairston*',
#                                              6284,
#                                              '48.51%'],
#                                          ['William Calloway', 3464, '26.74%'],
#                                          ['Gabriel Piemonte', 3205, '24.74%'],
#                                          ['Write-in', 1, '0.01%']],
#                             'meta': ['Alderman 5th Ward', 41, 41, 12954]},
#                 '0018': {   'cands': [   [   'Roderick T. Sawyer*',
#                                              5053,
#                                              '49.94%'],
#                                          [   'Deborah A. Foster-Bonner',
#                                              3159,
#                                              '31.22%'],
#                                          ['Richard A. Wooten', 1900, '18.78%'],
#                                          ['Write-in', 7, '0.07%']],
#                             'meta': ['Alderman 6th Ward', 48, 48, 10119]},
#                 '0019': {   'cands': [   [   'Gregory I. Mitchell*',
#                                              6684,
#                                              '66.30%'],
#                                          ['Jedidiah L. Brown', 2100, '20.83%'],
#                                          ['Charles Kyle', 1294, '12.83%'],
#                                          ['Write-in', 4, '0.04%']],
#                             'meta': ['Alderman 7th Ward', 46, 46, 10082]},
#                 '0020': {   'cands': [   [   'Michelle A. Harris*',
#                                              8723,
#                                              '64.35%'],
#                                          ['Linda Hudson', 2356, '17.38%'],
#                                          ['Faheem Shabazz', 1385, '10.22%'],
#                                          [   'Jewel R. Easterling-Smith',
#                                              1091,
#                                              '8.05%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 8th Ward', 56, 56, 13555]},
#                 '0021': {   'cands': [   ['Anthony A. Beale*', 6773, '59.25%'],
#                                          ['Cleopatra Watson', 2949, '25.80%'],
#                                          ['Paul Collins', 938, '8.21%'],
#                                          ['Essie Hall', 763, '6.67%'],
#                                          ['Write-in', 8, '0.07%']],
#                             'meta': ['Alderman 9th Ward', 51, 51, 11431]},
#                 '0022': {   'cands': [   [   'Susan Sadlowski Garza*',
#                                              5773,
#                                              '68.62%'],
#                                          [   'Robert "Bobby" Loncar',
#                                              2640,
#                                              '31.38%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 10th Ward', 36, 36, 8413]},
#                 '0023': {   'cands': [   [   'Patrick Daley Thompson*',
#                                              7537,
#                                              '73.44%'],
#                                          ['David Mihalyfy', 2726, '26.56%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 11th Ward', 38, 38, 10263]},
#                 '0024': {   'cands': [   ['George Cardenas*', 2987, '50.21%'],
#                                          ['Pete Demay', 1019, '17.13%'],
#                                          ['Jose Rico', 1006, '16.91%'],
#                                          [   'Martha Yerania Rangel',
#                                              929,
#                                              '15.62%'],
#                                          ['Write-in', 8, '0.13%']],
#                             'meta': ['Alderman 12th Ward', 23, 23, 5949]},
#                 '0025': {   'cands': [   ['Marty Quinn*', 10759, '86.04%'],
#                                          ['David J. Krupa', 1746, '13.96%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 13th Ward', 48, 48, 12505]},
#                 '0026': {   'cands': [   ['Edward M. Burke*', 3917, '54.24%'],
#                                          ['Tanya G. Patino', 2123, '29.40%'],
#                                          ['Jaime Guzman', 1181, '16.36%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 14th Ward', 31, 31, 7221]},
#                 '0027': {   'cands': [   ['Raymond A. Lopez*', 2541, '49.70%'],
#                                          [   'Rafael "Rafa" Yanez',
#                                              1116,
#                                              '21.83%'],
#                                          ['Berto Aguayo', 833, '16.29%'],
#                                          ['Joseph G. Williams', 413, '8.08%'],
#                                          ['Otis Davis Jr.', 210, '4.11%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 15th Ward', 24, 24, 5113]},
#                 '0028': {   'cands': [   [   'Stephanie D. Coleman',
#                                              2464,
#                                              '44.12%'],
#                                          ['Toni L. Foulkes*', 1758, '31.48%'],
#                                          ['Latasha M. Sanders', 540, '9.67%'],
#                                          ['Eddie Johnson III', 371, '6.64%'],
#                                          ['Kenny C. Doss II', 364, '6.52%'],
#                                          ['Jeffrey L. Lewis', 88, '1.58%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 16th Ward', 36, 36, 5585]},
#                 '0029': {   'cands': [   ['David H. Moore*', 5316, '67.21%'],
#                                          ['Raynetta Greenleaf', 2594, '32.79%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 17th Ward', 41, 41, 7910]},
#                 '0030': {   'cands': [   ['Derrick G. Curtis*', 8050, '67.32%'],
#                                          ['Chuks Onyezia', 3904, '32.65%'],
#                                          ['Write-in', 3, '0.03%']],
#                             'meta': ['Alderman 18th Ward', 50, 50, 11957]},
#                 '0031': {   'cands': [   [   "Matthew J. O'Shea*",
#                                              17654,
#                                              '85.24%'],
#                                          ['David A. Dewar', 3056, '14.76%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 19th Ward', 57, 57, 20710]},
#                 '0032': {   'cands': [   ['Jeanette B Taylor', 2154, '28.78%'],
#                                          ['Nicole J. Johnson', 1644, '21.97%'],
#                                          ['Kevin M. Bailey', 1211, '16.18%'],
#                                          ['Maya Hodari', 701, '9.37%'],
#                                          ['Andre Smith', 600, '8.02%'],
#                                          ['Anthony Driver Jr.', 486, '6.49%'],
#                                          ['Jennifer O. Maddox', 460, '6.15%'],
#                                          ['Quandra V. Speights', 157, '2.10%'],
#                                          ['Dernard D. Newell', 71, '0.95%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 20th Ward', 39, 39, 7484]},
#                 '0033': {   'cands': [   [   'Howard B. Brookins Jr.*',
#                                              5700,
#                                              '45.82%'],
#                                          ['Marvin McNeil', 3143, '25.27%'],
#                                          ['Patricia A. Foster', 2382, '19.15%'],
#                                          [   'Joseph C. Ziegler Jr.',
#                                              1215,
#                                              '9.77%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 21st Ward', 54, 54, 12440]},
#                 '0034': {   'cands': [   [   'Michael D. Rodriguez',
#                                              3104,
#                                              '63.80%'],
#                                          ['Lisette "Liz" Lopez', 675, '13.87%'],
#                                          ['Richard Juarez', 610, '12.54%'],
#                                          ['Neftalie Gonzalez', 476, '9.78%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 22nd Ward', 25, 25, 4865]},
#                 '0035': {   'cands': [   ['Silvana Tabares*', 6702, '76.12%'],
#                                          [   'Paulino R. Villarreal Jr.',
#                                              2097,
#                                              '23.82%'],
#                                          ['Write-in', 5, '0.06%']],
#                             'meta': ['Alderman 23rd Ward', 39, 39, 8804]},
#                 '0036': {   'cands': [   ['Michael Scott Jr.*', 3809, '59.90%'],
#                                          ['Creative Scott', 1191, '18.73%'],
#                                          [   'Traci "Treasure" Johnson',
#                                              991,
#                                              '15.58%'],
#                                          ['Toriano A. Sanzone', 364, '5.72%'],
#                                          ['Write-in', 4, '0.06%']],
#                             'meta': ['Alderman 24th Ward', 41, 41, 6359]},
#                 '0037': {   'cands': [   ['Byron Sigcho-Lopez', 2885, '29.23%'],
#                                          [   'Alexander "Alex" Acevedo',
#                                              2182,
#                                              '22.11%'],
#                                          ['Hilario Dominguez', 2056, '20.83%'],
#                                          ['Aida Flores', 1912, '19.37%'],
#                                          [   'Troy Antonio Hernandez',
#                                              835,
#                                              '8.46%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 25th Ward', 32, 32, 9870]},
#                 '0038': {   'cands': [   ['Roberto Maldonado*', 4431, '50.53%'],
#                                          ['Theresa Siaw', 2467, '28.13%'],
#                                          ['David Herrera', 1866, '21.28%'],
#                                          ['Write-in', 5, '0.06%']],
#                             'meta': ['Alderman 26th Ward', 49, 49, 8769]},
#                 '0039': {   'cands': [   [   'Walter Burnett Jr.*',
#                                              6962,
#                                              '68.50%'],
#                                          ['Cynthia D. Bednarz', 3191, '31.40%'],
#                                          ['Write-in', 11, '0.11%']],
#                             'meta': ['Alderman 27th Ward', 50, 50, 10164]},
#                 '0040': {   'cands': [   ['Jason C. Ervin*', 4954, '61.20%'],
#                                          ['Jasmine Jackson', 1230, '15.19%'],
#                                          ['Miguel Bautista', 1122, '13.86%'],
#                                          ['Beverly Miles', 764, '9.44%'],
#                                          ['Write-in', 25, '0.31%']],
#                             'meta': ['Alderman 28th Ward', 46, 46, 8095]},
#                 '0041': {   'cands': [   ['Chris Taliaferro*', 6235, '58.72%'],
#                                          ['Dwayne Truss', 2915, '27.45%'],
#                                          ['Zerlina A. Smith', 1469, '13.83%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 29th Ward', 44, 44, 10619]},
#                 '0042': {   'cands': [   ['Ariel E. Reboyras*', 3563, '47.90%'],
#                                          [   'Jessica W. Gutierrez',
#                                              3536,
#                                              '47.54%'],
#                                          ['Edgar "Edek" Esparza', 339, '4.56%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 30th Ward', 32, 32, 7438]},
#                 '0043': {   'cands': [   [   'Milagros "Milly" Santiago*',
#                                              2588,
#                                              '40.32%'],
#                                          ['Felix Cardona Jr.', 2132, '33.21%'],
#                                          [   'Colin Bird-Martinez',
#                                              1699,
#                                              '26.47%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 31st Ward', 41, 41, 6419]},
#                 '0044': {   'cands': [   [   'Scott Waguespack*',
#                                              11519,
#                                              '100.00%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 32nd Ward', 43, 43, 11519]},
#                 '0045': {   'cands': [   [   'Rossana Rodríguez-Sánchez',
#                                              4598,
#                                              '42.05%'],
#                                          ['Deborah L. Mell*', 4515, '41.29%'],
#                                          ['Katie Sieracki', 1822, '16.66%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 33rd Ward', 28, 28, 10935]},
#                 '0046': {   'cands': [   ['Carrie M. Austin*', 6306, '54.31%'],
#                                          ['Preston Brown Jr.', 5294, '45.59%'],
#                                          ['Write-in', 12, '0.10%']],
#                             'meta': ['Alderman 34th Ward', 53, 53, 11612]},
#                 '0047': {   'cands': [   [   'Carlos Ramirez-Rosa*',
#                                              4700,
#                                              '59.43%'],
#                                          [   'Amanda Yu Dieterich',
#                                              3208,
#                                              '40.57%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 35th Ward', 31, 31, 7908]},
#                 '0048': {   'cands': [   ['Gilbert Villegas*', 5376, '99.98%'],
#                                          ['Write-in', 1, '0.02%']],
#                             'meta': ['Alderman 36th Ward', 30, 30, 5377]},
#                 '0049': {   'cands': [   ['Emma M. Mitts*', 4151, '54.08%'],
#                                          ['Tara Stamps', 3083, '40.17%'],
#                                          ['Deondre Rutues', 436, '5.68%'],
#                                          ['Write-in', 5, '0.07%']],
#                             'meta': ['Alderman 37th Ward', 41, 41, 7675]},
#                 '0050': {   'cands': [   ['Nicholas Sposato*', 9340, '100.00%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 38th Ward', 41, 41, 9340]},
#                 '0051': {   'cands': [   [   'Samantha "Sam" Nugent',
#                                              4396,
#                                              '33.20%'],
#                                          ['Robert Murphy', 3914, '29.56%'],
#                                          ['Casey Smagala', 3644, '27.52%'],
#                                          ['Joe Duplechin', 1287, '9.72%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 39th Ward', 45, 45, 13241]},
#                 '0052': {   'cands': [   [   "Patrick J. O'Connor*",
#                                              4446,
#                                              '33.30%'],
#                                          ['Andre Vasquez', 2683, '20.09%'],
#                                          ['Dianne Daleiden', 2296, '17.19%'],
#                                          ["Maggie O'Keefe", 2058, '15.41%'],
#                                          ['Ugo Okere', 1870, '14.00%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 40th Ward', 39, 39, 13353]},
#                 '0053': {   'cands': [   [   'Anthony V. Napolitano*',
#                                              12502,
#                                              '70.27%'],
#                                          ['Tim Heneghan', 5289, '29.73%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 41st Ward', 47, 47, 17791]},
#                 '0054': {   'cands': [   ['Brendan Reilly*', 11129, '100.00%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 42nd Ward', 42, 42, 11129]},
#                 '0055': {   'cands': [   ['Michele Smith*', 5486, '38.98%'],
#                                          ['Derek Lindblom', 3913, '27.81%'],
#                                          ['Leslie Fox', 1892, '13.44%'],
#                                          ['Jacob Ringer', 1776, '12.62%'],
#                                          ['Rebecca Janowitz', 681, '4.84%'],
#                                          ['Steven McClellan', 325, '2.31%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 43rd Ward', 46, 46, 14073]},
#                 '0056': {   'cands': [   ['Tom Tunney*', 9734, '64.44%'],
#                                          ['Austin Baidas', 3794, '25.12%'],
#                                          [   'Elizabeth Shydlowski',
#                                              1577,
#                                              '10.44%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 44th Ward', 41, 41, 15105]},
#                 '0057': {   'cands': [   [   'James "Jim" Gardiner',
#                                              7570,
#                                              '50.92%'],
#                                          ['John S. Arena*', 5382, '36.21%'],
#                                          ['Marilyn Morales', 1353, '9.10%'],
#                                          ['Robert A. Bank', 553, '3.72%'],
#                                          ['Write-in', 7, '0.05%']],
#                             'meta': ['Alderman 45th Ward', 48, 48, 14865]},
#                 '0058': {   'cands': [   ['James Cappleman*', 6082, '44.07%'],
#                                          ['Marianne Lalonde', 2494, '18.07%'],
#                                          [   'Erika Wozniak Francis',
#                                              2324,
#                                              '16.84%'],
#                                          ['Angela Clay', 2127, '15.41%'],
#                                          ['Justin Kreindler', 545, '3.95%'],
#                                          ['Jon-Robert McDowell', 229, '1.66%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 46th Ward', 40, 40, 13801]},
#                 '0059': {   'cands': [   ['Matt Martin', 7586, '39.31%'],
#                                          ['Michael A. Negron', 4126, '21.38%'],
#                                          ['Eileen Dordek', 3373, '17.48%'],
#                                          ['Jeff Jenkins', 1602, '8.30%'],
#                                          ['Heather Way Kitzes', 931, '4.82%'],
#                                          [   'Angela "Angie" Maloney',
#                                              888,
#                                              '4.60%'],
#                                          [   'Thomas M. Schwartzers',
#                                              372,
#                                              '1.93%'],
#                                          ['Gus Katsafaros', 344, '1.78%'],
#                                          ['Kimball Ladien', 75, '0.39%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 47th Ward', 48, 48, 19297]},
#                 '0060': {   'cands': [   ['Harry Osterman*', 12442, '83.73%'],
#                                          [   'David Earl Williams III',
#                                              2415,
#                                              '16.25%'],
#                                          ['Write-in', 2, '0.01%']],
#                             'meta': ['Alderman 48th Ward', 46, 46, 14859]},
#                 '0061': {   'cands': [   ['Maria Hadden', 7820, '63.37%'],
#                                          ['Joe Moore*', 4514, '36.58%'],
#                                          ['Write-in', 7, '0.06%']],
#                             'meta': ['Alderman 49th Ward', 33, 33, 12341]},
#                 '0062': {   'cands': [   [   'Debra L. Silverstein*',
#                                              6014,
#                                              '65.84%'],
#                                          ['Andrew D. Rowlas', 1678, '18.37%'],
#                                          ['Zehra Quadri', 1442, '15.79%'],
#                                          ['Write-in', 0, '0.00%']],
#                             'meta': ['Alderman 50th Ward', 40, 40, 9134]}})

# %%
contest_headers = ['name', 'prs_rpt', 'prs_tot', 'vote_tot']
cand_headers = ['name', 'vote_cnt', 'vote_pct']
cand_classes = ['', 'amt', 'amt append-bar']

idx_total_votes = contest_headers.index('vote_tot')
idx_cand_votes = cand_headers.index('vote_cnt')

def assign_winners(contests):
    from operator import itemgetter
    
    for idx, contest in contests.items():
        meta, cands = itemgetter('meta', 'cands')(contest)
        
        total_votes = meta[idx_total_votes]
        
        # does the candidate with the most votes have >50%?
        top_cand = cands[0]
        has_winner = top_cand[idx_cand_votes] / total_votes > 0.5
        
        # add empty winner column to cand row
        cands = list(map(lambda x: ['', *x], cands))

        if has_winner:
            cands[0] = ['✓', *cands[0][1:]]
        
        else:
            cands[0] = ['✓', *cands[0][1:]]
            cands[1] = ['✓', *cands[1][1:]]
        
        contests[idx] = {'meta': meta, 'cands': cands}
        
        
    return contests

assigned_contests = assign_winners(contests)
cand_headers = ['winner', *cand_headers]
cand_classes = ['', *cand_classes]

# %%
def validate(contests):
    from operator import itemgetter
    
    for idx, contest in contests.items():
        meta, cands = itemgetter('meta', 'cands')(contest)
        
        total_votes = meta[idx_total_votes]
        
        # do the candidates add up to the total?
        votes = [c[2] for c in cands]
        try:
            assert total_votes == sum(votes)
        except AsseritionError:
            print(meta[0], '\tbad total')
        
        my_pcts = ["%.2f%%" % (v*100) for v in [v/total_votes for v in votes]]
        
        pcts = [c[3] for c in cands]

        try:
            assert my_pcts == pcts
        except AssertionError:
            print(meta[0], '\tbad percent')
    
validate(contests)

# %%
import datetime

results = {
    'contest_headers': contest_headers,
    'cand_headers': cand_headers,
    'contests': assigned_contests,
    'cand_classes': cand_classes,
    'datetime': datetime.date(2019, 3, 13).isoformat(),
    'isFinal': True
}

# %%
class MyEncoder(json.JSONEncoder):
    """
    We have to use a custom encoder because pandas uses special numpy
    object types that json doesn't like.
    Source: https://stackoverflow.com/a/27050186
    """

    def default(self, obj):
        import numpy as np

        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

with open('results.json', 'w') as outfile:
    json.dump(results, outfile, cls=MyEncoder)
